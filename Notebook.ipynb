# %%
import draw
import data

# %%
draw = draw.Draw()

# %%
paths = draw.draw_plots(data=data.data)

# %%
paths
# Out:
# ['plots\\max_min.png',
#  'plots\\corners.png',
#  'plots\\max_min.png',
#  'plots\\corners.png']
